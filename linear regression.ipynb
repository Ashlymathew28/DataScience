# %%
import pandas as pd
data=pd.read_csv("C:/Users/ashly/OneDrive/Desktop/DataScience Anaconda/Regression/train.csv")

# %%
data
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data.shape
# Out:
# (700, 2)

# %%
data.isnull()
# Out:
#          x      y
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# 5    False  False
# 6    False  False
# 7    False  False
# 8    False  False
# 9    False  False
# 10   False  False
# 11   False  False
# 12   False  False
# 13   False  False
# 14   False  False
# 15   False  False
# 16   False  False
# 17   False  False
# 18   False  False
# 19   False  False
# 20   False  False
# 21   False  False
# 22   False  False
# 23   False  False
# 24   False  False
# 25   False  False
# 26   False  False
# 27   False  False
# 28   False  False
# 29   False  False
# 30   False  False
# 31   False  False
# 32   False  False
# 33   False  False
# 34   False  False
# 35   False  False
# 36   False  False
# 37   False  False
# 38   False  False
# 39   False  False
# 40   False  False
# 41   False  False
# 42   False  False
# 43   False  False
# 44   False  False
# 45   False  False
# 46   False  False
# 47   False  False
# 48   False  False
# ...

# %%
data.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
data=data.drop(data[data['x']==0.000000].index)
data=data.dropna()

# %%
data
# Out:
#          x           y
# 0     24.0   21.549452
# 1     50.0   47.464463
# 2     15.0   17.218656
# 3     38.0   36.586398
# 4     87.0   87.288984
# 5     36.0   32.463875
# 6     12.0   10.780897
# 7     81.0   80.763399
# 8     25.0   24.612151
# 9      5.0    6.963319
# 10    16.0   11.237573
# 11    16.0   13.532902
# 12    24.0   24.603239
# 13    39.0   39.400500
# 14    54.0   48.437538
# 15    60.0   61.699003
# 16    26.0   26.928324
# 17    73.0   70.405205
# 18    29.0   29.340924
# 19    31.0   25.308952
# 20    68.0   69.029343
# 21    87.0   84.994847
# 22    58.0   57.043103
# 23    54.0   50.592199
# 24    84.0   83.027722
# 25    58.0   57.057527
# 26    49.0   47.958833
# 27    20.0   24.342264
# 28    90.0   94.684883
# 29    48.0   48.039707
# 30     4.0    7.081323
# 31    25.0   21.992399
# 32    42.0   42.331517
# 34    60.0   61.923037
# 35    93.0   91.177164
# 36    39.0   39.453580
# 37     7.0    5.996070
# 38    21.0   22.590159
# 39    68.0   61.180444
# ...

# %%
data.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,1].values

# %%
print("x",x)
print("y",y)
# Out:
# x [[ 24.]
#  [ 50.]
#  [ 15.]
#  [ 38.]
#  [ 87.]
#  [ 36.]
#  [ 12.]
#  [ 81.]
#  [ 25.]
#  [  5.]
#  [ 16.]
#  [ 16.]
#  [ 24.]
#  [ 39.]
#  [ 54.]
#  [ 60.]
#  [ 26.]
#  [ 73.]
#  [ 29.]
#  [ 31.]
#  [ 68.]
#  [ 87.]
#  [ 58.]
#  [ 54.]
#  [ 84.]
#  [ 58.]
#  [ 49.]
#  [ 20.]
#  [ 90.]
#  [ 48.]
#  [  4.]
#  [ 25.]
#  [ 42.]
#  [ 60.]
#  [ 93.]
#  [ 39.]
#  [  7.]
#  [ 21.]
#  [ 68.]
#  [ 84.]
#  [ 58.]
#  [ 19.]
#  [ 36.]
#  [ 19.]
#  [ 59.]
#  [ 51.]
#  [ 19.]
#  [ 33.]
#  [ 85.]
#  [ 44.]
#  [  5.]
#  [ 59.]
#  [ 14.]
#  [  9.]
#  [ 75.]
#  [ 69.]
#  [ 10.]
#  [ 17.]
#  [ 58.]
#  [ 74.]
#  [ 21.]
#  [ 51.]
#  [ 19.]
#  [ 50.]
#  [ 24.]
#  [ 12.]
#  [ 75.]
#  [ 21.]
#  [ 64.]
#  [  5.]
#  [ 58.]
#  [ 32.]
#  [ 41.]
#  [  7.]
#  [  4.]
#  [  5.]
#  [ 49.]
#  [ 90.]
#  [  3.]
#  [ 11.]
#  [ 32.]
#  [ 83.]
#  [ 25.]
#  [ 83.]
#  [ 26.]
#  [ 76.]
#  [ 95.]
#  [ 53.]
#  [ 77.]
#  [ 42.]
#  [ 25.]
#  [ 54.]
#  [ 55.]
#  [ 73.]
#  [ 35.]
#  [ 86.]
#  [ 90.]
#  [ 13.]
#  [ 46.]
# ...

# %%
import matplotlib.pyplot as mlt
graph=mlt.plot(x,y,'o:g')
graph

# %%
data.describe()
# Out:
#                 x           y
# count  691.000000  691.000000
# mean    50.593343   50.518852
# std     28.613788   28.771555
# min      1.000000   -3.839981
# 25%     26.000000   25.500227
# 50%     50.000000   49.447854
# 75%     75.000000   75.193074
# max    100.000000  108.871618

# %%
pd.DataFrame(data['x'].describe(percentiles=(1,.9,.99,.8,.7,.6,.5,.4,.3,.2,.1,.01)))
# Out:
#                 x
# count  691.000000
# mean    50.593343
# std     28.613788
# min      1.000000
# 1%       2.000000
# 10%     12.000000
# 20%     22.000000
# 30%     30.000000
# 40%     42.000000
# 50%     50.000000
# 60%     58.000000
# 70%     70.000000
# 80%     81.000000
# 90%     91.000000
# 99%    100.000000
# 100%   100.000000
# max    100.000000

# %%
# %matplotlib inline
mlt.boxplot(data['x'])
mlt.show()

# %%
x_val=pd.DataFrame(data['x'])
x_median=x_val.median()

# %%
# IQR of age
q3=x_val.quantile(q=.75)
q1=x_val.quantile(q=.25)
iqr=q3-q1

# deriving bounderies of outlier
iqr_ll=int(q1 - 1.5 * iqr)
iqr_ul=int(q3 + 1.5 * iqr)

#finding and treating outliers lower limit and upper limit
data.loc[data['x']>iqr_ul,'x'] = int(x_val.quantile(q=.99))
data.loc[data['x']<iqr_ll,'x'] = int(x_val.quantile(q=.01))

# %%
max(data['x'])
# Out:
# 100.0

# %%
mlt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
regression=LinearRegression()
y_pred=regression.fit(x_train,y_train)

# %%
accuracy=regression.score(x_test,y_test)
print("acccuracy",accuracy)
# Out:
# acccuracy 0.9902984809712653

# %%
test=pd.read_csv("C:/Users/ashly/OneDrive/Desktop/DataScience Anaconda/Regression/test.csv")

# %%
test
# Out:
#        x           y
# 0     77   79.775152
# 1     21   23.177279
# 2     22   25.609262
# 3     20   17.857388
# 4     36   41.849864
# 5     15    9.805235
# 6     62   58.874659
# 7     95   97.617937
# 8     20   18.395127
# 9      5    8.746748
# 10     4    2.811416
# 11    19   17.095372
# 12    96   95.149072
# 13    62   61.388007
# 14    36   40.247017
# 15    15   14.822486
# 16    65   66.958069
# 17    14   16.635080
# 18    87   90.655137
# 19    69   77.229826
# 20    89   92.119063
# 21    51   46.913877
# 22    89   89.826344
# 23    27   21.713803
# 24    97   97.412070
# 25    58   57.016314
# 26    79   78.310565
# 27    21   19.131510
# 28    93   93.034834
# 29    27   26.591124
# 30    99   97.551553
# 31    31   31.435248
# 32    33   35.127248
# 33    80   78.610424
# 34    28   33.071128
# 35    47   51.699672
# 36    53   53.622352
# 37    69   69.463061
# 38    28   27.424972
# 39    33   36.346442
# 40    91   95.061409
# 41    71   68.167248
# ...

# %%
test_x=test.iloc[:,:-1]
test_y=test.iloc[:,1]
y_pred=regression.predict(test_x)
y_pred
# Out:
# C:\Users\ashly\anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([ 7.69353020e+01,  2.09327192e+01,  2.19327654e+01,  1.99326731e+01,
#         3.59334110e+01,  1.49324425e+01,  6.19346102e+01,  9.49361322e+01,
#         1.99326731e+01,  4.93198129e+00,  3.93193517e+00,  1.89326270e+01,
#         9.59361783e+01,  6.19346102e+01,  3.59334110e+01,  1.49324425e+01,
#         6.49347486e+01,  1.39323964e+01,  8.69357632e+01,  6.89349330e+01,
#         8.89358555e+01,  5.09341029e+01,  8.89358555e+01,  2.69329960e+01,
#         9.69362244e+01,  5.79344257e+01,  7.89353943e+01,  2.09327192e+01,
#         9.29360400e+01,  2.69329960e+01,  9.89363167e+01,  3.09331804e+01,
#         3.29332727e+01,  7.99354404e+01,  2.79330421e+01,  4.69339184e+01,
#         5.29341951e+01,  6.89349330e+01,  2.79330421e+01,  3.29332727e+01,
# ...

# %%
test_y
# Out:
# 0       79.775152
# 1       23.177279
# 2       25.609262
# 3       17.857388
# 4       41.849864
# 5        9.805235
# 6       58.874659
# 7       97.617937
# 8       18.395127
# 9        8.746748
# 10       2.811416
# 11      17.095372
# 12      95.149072
# 13      61.388007
# 14      40.247017
# 15      14.822486
# 16      66.958069
# 17      16.635080
# 18      90.655137
# 19      77.229826
# 20      92.119063
# 21      46.913877
# 22      89.826344
# 23      21.713803
# 24      97.412070
# 25      57.016314
# 26      78.310565
# 27      19.131510
# 28      93.034834
# 29      26.591124
# 30      97.551553
# 31      31.435248
# 32      35.127248
# 33      78.610424
# 34      33.071128
# 35      51.699672
# 36      53.622352
# 37      69.463061
# 38      27.424972
# 39      36.346442
# 40      95.061409
# 41      68.167248
# 42      50.961555
# 43      78.042375
# 44       5.607665
# 45      36.113348
# 46      67.235215
# 47      65.013240
# 48      38.147539
# 49      34.311414
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import numpy as np
mae=mean_absolute_error(test_y,y_pred)
mse=mean_squared_error(test_y,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(test_y,y_pred)

# %%
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Absolute Error (MAE): 2.42
# Mean Squared Error (MSE): 9.44
# Root Mean Squared Error (RMSE): 3.07
# R-squared (R2): 0.99
